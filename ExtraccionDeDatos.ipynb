# %%
from pymongo import MongoClient
import pandas as pd

# %%
# Conexión a la base de datos local de MongoDB
local_client = MongoClient('localhost', 27017)

# %%
# Conexión a las colecciones locales
local_db1 = local_client['FutbolData']
local_collection1 = local_db1['RankingDeEquipos']

local_db2 = local_client['FutbolData']
local_collection2 = local_db2['RankingDeJugadores']

# %%
# Conexión a la base de datos de MongoDB Atlas
atlas_client = MongoClient('mongodb+srv://shazam:shazam123456@proyecto1.g6uwmfh.mongodb.net/')
atlas_db = atlas_client['proyecto']
atlas_collection = atlas_db['Futbol']

# %%
# Obtener todos los documentos de la primera colección local
documents1 = local_collection1.find()

# Convertir documentos1 en un DataFrame
df1 = pd.DataFrame(list(documents1))

# Insertar el DataFrame en la colección de MongoDB Atlas
atlas_collection.insert_many(df1.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('65e3f441f78ded2816e4edb0'), ObjectId('65e3f441f78ded2816e4edb1'), ObjectId('65e3f441f78ded2816e4edb2'), ObjectId('65e3f441f78ded2816e4edb3'), ObjectId('65e3f441f78ded2816e4edb4'), ObjectId('65e3f441f78ded2816e4edb5'), ObjectId('65e3f441f78ded2816e4edb6'), ObjectId('65e3f441f78ded2816e4edb7'), ObjectId('65e3f441f78ded2816e4edb8'), ObjectId('65e3f441f78ded2816e4edb9'), ObjectId('65e3f441f78ded2816e4edba'), ObjectId('65e3f441f78ded2816e4edbb'), ObjectId('65e3f441f78ded2816e4edbc'), ObjectId('65e3f441f78ded2816e4edbd'), ObjectId('65e3f441f78ded2816e4edbe'), ObjectId('65e3f441f78ded2816e4edbf'), ObjectId('65e3f441f78ded2816e4edc0'), ObjectId('65e3f441f78ded2816e4edc1'), ObjectId('65e3f441f78ded2816e4edc2'), ObjectId('65e3f441f78ded2816e4edc3'), ObjectId('65e3f441f78ded2816e4edc4'), ObjectId('65e3f441f78ded2816e4edc5'), ObjectId('65e3f441f78ded2816e4edc6'), ObjectId('65e3f441f78ded2816e4edc7'), ObjectId('65e3f441f78ded2816e4edc8'), ObjectId('65e3f441f78ded2816e4
# ...

# %%
# Obtener todos los documentos de la primera colección local
documents2 = local_collection2.find()

# Convertir documentos1 en un DataFrame
df2 = pd.DataFrame(list(documents2))

# Insertar el DataFrame en la colección de MongoDB Atlas
atlas_collection.insert_many(df2.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('65e3f42a611ce695dacfebf7'), ObjectId('65e3f42a611ce695dacfebf8'), ObjectId('65e3f42a611ce695dacfebf9'), ObjectId('65e3f42a611ce695dacfebfa'), ObjectId('65e3f42a611ce695dacfebfb'), ObjectId('65e3f42a611ce695dacfebfc'), ObjectId('65e3f42a611ce695dacfebfd'), ObjectId('65e3f42a611ce695dacfebfe'), ObjectId('65e3f42a611ce695dacfebff'), ObjectId('65e3f42a611ce695dacfec00'), ObjectId('65e3f42a611ce695dacfec01'), ObjectId('65e3f42a611ce695dacfec02'), ObjectId('65e3f42a611ce695dacfec03'), ObjectId('65e3f42a611ce695dacfec04'), ObjectId('65e3f42a611ce695dacfec05'), ObjectId('65e3f42a611ce695dacfec06'), ObjectId('65e3f42a611ce695dacfec07'), ObjectId('65e3f42a611ce695dacfec08'), ObjectId('65e3f42a611ce695dacfec09'), ObjectId('65e3f42a611ce695dacfec0a'), ObjectId('65e3f42a611ce695dacfec0b'), ObjectId('65e3f42a611ce695dacfec0c'), ObjectId('65e3f42a611ce695dacfec0d'), ObjectId('65e3f42a611ce695dacfec0e'), ObjectId('65e3f42a611ce695dacfec0f'), ObjectId('65e3f42a611ce695dacf
# ...

# %%
# Cerrar las conexiones
local_client.close()
atlas_client.close()
